# %%
import optuna
import pandas as pd
import os
import joblib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import time
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder

# %%
# === PATHS ===
SCRIPT_PATH = os.getcwd()
DATA_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'data', 'preprocessed', 'analysis_data'))
MODELS_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'models','random_forest'))
RESULTS_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'results', 'random_forest'))
FEATURES_NAMES_DIR = os.path.abspath(os.path.join(DATA_DIR,'feature_names.pkl'))
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)
# Load preprocessed data
train_data = pd.read_csv(os.path.join(DATA_DIR, 'train.csv'))
#val_data = pd.read_csv(os.path.join(DATA_DIR, 'val.csv'))
test_data = pd.read_csv(os.path.join(DATA_DIR, 'test.csv'))

# Load feature names from saved file
feature_cols = joblib.load(FEATURES_NAMES_DIR)
target_col = 'Fault_Condition'

# %%
# Prepare features and labels
X_train = train_data[feature_cols]
y_train_raw = train_data[target_col]
X_test = test_data[feature_cols]
y_test_raw = test_data[target_col]

le = LabelEncoder()
y_train = le.fit_transform(y_train_raw)
y_test = le.transform(y_test_raw)
print("Mapowanie klas:", dict(zip(le.classes_, le.transform(le.classes_))))
y_map = le.classes_
# Global dictionary for optimization results
results = {}
# Out:
# Mapowanie klas: {'faulty': np.int64(0), 'faulty_zip': np.int64(1), 'healthy': np.int64(2), 'healthy_zip': np.int64(3)}

# %%
# Train Random Forest model with optimized parameters by optuna
def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 200)
    max_depth    = trial.suggest_int("max_depth", 5, 20)
    min_split    = trial.suggest_int("min_samples_split", 2, 10)
    rf_model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_split,
        random_state=42,
        n_jobs=-1
    )
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(rf_model, X_train, y_train, cv=cv, scoring='accuracy')

    return np.mean(scores)

# %%
start = time.time()
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)
t_optuna = time.time() - start

acc_optuna = study.best_value
best_trial = study.best_trial.number

print("Optuna:", study.best_params, "Acc:", acc_optuna, "Time:", round(t_optuna,2),"s")
# Out:
# [I 2026-02-23 21:24:31,920] A new study created in memory with name: no-name-25cd609d-f266-4449-a01d-9c3925b896dc
# [I 2026-02-23 21:24:32,917] Trial 0 finished with value: 0.8516923076923076 and parameters: {'n_estimators': 186, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 0 with value: 0.8516923076923076.
# [I 2026-02-23 21:24:33,930] Trial 1 finished with value: 0.8443076923076923 and parameters: {'n_estimators': 197, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 0 with value: 0.8516923076923076.
# [I 2026-02-23 21:24:34,936] Trial 2 finished with value: 0.8596923076923076 and parameters: {'n_estimators': 192, 'max_depth': 7, 'min_samples_split': 2}. Best is trial 2 with value: 0.8596923076923076.
# [I 2026-02-23 21:24:35,821] Trial 3 finished with value: 0.86 and parameters: {'n_estimators': 166, 'max_depth': 17, 'min_samples_split': 8}. Best is trial 3 with value: 0.86.
# [I 2026-02-23 21:24:36,476] Trial 4 finished with value: 0.8676923076923077 and parameters: {'n_estimators': 126, 'max_depth': 15, 'min_samples_split': 8}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:37,249] Trial 5 finished with value: 0.86 and parameters: {'n_estimators': 148, 'max_depth': 6, 'min_samples_split': 8}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:38,232] Trial 6 finished with value: 0.8516923076923076 and parameters: {'n_estimators': 191, 'max_depth': 11, 'min_samples_split': 5}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:39,305] Trial 7 finished with value: 0.852 and parameters: {'n_estimators': 193, 'max_depth': 14, 'min_samples_split': 2}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:40,313] Trial 8 finished with value: 0.8363076923076923 and parameters: {'n_estimators': 194, 'max_depth': 11, 'min_samples_split': 3}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:41,107] Trial 9 finished with value: 0.8523076923076923 and parameters: {'n_estimators': 153, 'max_depth': 17, 'min_samples_split': 10}. Best is trial 4 with value: 0.8676923076923077.
# [I 2026-02-23 21:24:41,667] Trial 10 finished with value: 0.8830769230769231 and parameters: {'n_estimators': 89, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:42,286] Trial 11 finished with value: 0.8676923076923077 and parameters: {'n_estimators': 85, 'max_depth': 14, 'min_samples_split': 5}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:42,861] Trial 12 finished with value: 0.8596923076923076 and parameters: {'n_estimators': 97, 'max_depth': 15, 'min_samples_split': 6}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:43,472] Trial 13 finished with value: 0.8750769230769231 and parameters: {'n_estimators': 114, 'max_depth': 10, 'min_samples_split': 4}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:43,889] Trial 14 finished with value: 0.8750769230769231 and parameters: {'n_estimators': 60, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:44,484] Trial 15 finished with value: 0.8747692307692307 and parameters: {'n_estimators': 105, 'max_depth': 9, 'min_samples_split': 4}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:44,942] Trial 16 finished with value: 0.852 and parameters: {'n_estimators': 69, 'max_depth': 12, 'min_samples_split': 4}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:45,599] Trial 17 finished with value: 0.8676923076923077 and parameters: {'n_estimators': 119, 'max_depth': 9, 'min_samples_split': 6}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:46,110] Trial 18 finished with value: 0.8753846153846153 and parameters: {'n_estimators': 85, 'max_depth': 17, 'min_samples_split': 3}. Best is trial 10 with value: 0.8830769230769231.
# [I 2026-02-23 21:24:46,577] Trial 19 finished with value: 0.8673846153846153 and parameters: {'n_estimators': 73, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 10 with value: 0.8830769230769231.
# Optuna: {'n_estimators': 89, 'max_depth': 14, 'min_samples_split': 5} Acc: 0.8830769230769231 Time: 14.66 s

# %%
best_model = RandomForestClassifier(**study.best_params, random_state=42, n_jobs=-1)
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

print("\nTest Accuracy:", round(accuracy_score(y_test, y_pred), 4))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9286
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.93      1.00      0.97        14
#            2       0.92      0.86      0.89        14
#            3       0.87      0.93      0.90        14
#
#     accuracy                           0.93        56
#    macro avg       0.93      0.93      0.93        56
# weighted avg       0.93      0.93      0.93        56

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=y_map)
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix - Random Forest")
plt.savefig(os.path.join(RESULTS_DIR, 'RF_CM.png'))
plt.show()

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
model = RandomForestClassifier(**study.best_params, random_state=42, n_jobs=-1)
fold_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')

plt.figure(figsize=(6,4))
plt.plot(range(1, 6), fold_scores, marker='o')
plt.title("Accuracy per fold (5-fold CV)")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %%
importances = pd.Series(best_model.feature_importances_, index=feature_cols).sort_values(ascending=False)
plt.figure(figsize=(8, 5))
importances.head(10).plot(kind='barh')
plt.title(f"Top 10 Feature Importances ({type(best_model).__name__})")
plt.xlabel("Mean Decrease in Score")
plt.gca().invert_yaxis()
plt.savefig(os.path.join(RESULTS_DIR, 'RF_feature_importance.png'))
plt.show()

# %%
# Save the trained model
MODEL_PATH = os.path.join(MODELS_DIR, 'random_forest.pkl')
joblib.dump(best_model, MODEL_PATH)
print(f"\nModel saved to: {MODEL_PATH}")

encoder_filename = 'label_encoder.pkl'
encoder_path = os.path.join(MODELS_DIR, encoder_filename)
joblib.dump(le, encoder_path)
print(f"Label Encoder saved to: {encoder_path}")
# Out:
# Model saved to: C:\Users\Jakub\Kuba_lokalne\studia\Praca_magisterska\Projekt\Fault-detection-in-mechanical-devices\models\random_forest\random_forest.pkl
# Label Encoder saved to: C:\Users\Jakub\Kuba_lokalne\studia\Praca_magisterska\Projekt\Fault-detection-in-mechanical-devices\models\random_forest\label_encoder.pkl
