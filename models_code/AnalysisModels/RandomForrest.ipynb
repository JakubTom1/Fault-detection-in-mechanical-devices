# %%
import optuna
import pandas as pd
import os
import joblib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import time
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
import warnings
warnings.filterwarnings('ignore')

# %%
# === PATHS ===
SCRIPT_PATH = os.getcwd()
DATA_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'data', 'preprocessed', 'analysis_data'))
MODELS_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'models','random_forest'))
RESULTS_DIR = os.path.abspath(os.path.join(SCRIPT_PATH, '..', '..', 'results', 'random_forest'))
FEATURES_NAMES_DIR = os.path.abspath(os.path.join(DATA_DIR,'feature_names.pkl'))
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)
# Load preprocessed data
train_data = pd.read_csv(os.path.join(DATA_DIR, 'train.csv'))
#val_data = pd.read_csv(os.path.join(DATA_DIR, 'val.csv'))
test_data = pd.read_csv(os.path.join(DATA_DIR, 'test.csv'))

# Load feature names from saved file
feature_cols = joblib.load(FEATURES_NAMES_DIR)
target_col = 'Fault_Condition'

# %%
# === DATA LOADING ===
X_train = train_data[feature_cols]
y_train_raw = train_data[target_col]
X_test = test_data[feature_cols]
y_test_raw = test_data[target_col]

le = LabelEncoder()
y_train = le.fit_transform(y_train_raw)
y_test = le.transform(y_test_raw)
print("Mapowanie klas:", dict(zip(le.classes_, le.transform(le.classes_))))
y_map = le.classes_
# Global dictionary for optimization results
results = {}
# Out:
# Mapowanie klas: {'faulty': np.int64(0), 'faulty_zip': np.int64(1), 'healthy': np.int64(2), 'healthy_zip': np.int64(3)}

# %%
# === TRAINING AND OPTIMIZATION FOR NESTED CV===
X_full = pd.concat([X_train, X_test], axis=0).reset_index(drop=True)
y_full = np.concatenate([y_train, y_test])
optuna.logging.set_verbosity(optuna.logging.WARNING)

outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
outer_acc, outer_prec, outer_rec, outer_f1 = [], [], [], []
fold_idx = 1

start = time.time()
for train_idx, test_idx in outer_cv.split(X_full, y_full):
    print(f"--- Fold {fold_idx}/5 ---")
    X_outer_train, X_outer_test = X_full.iloc[train_idx], X_full.iloc[test_idx]
    y_outer_train, y_outer_test = y_full[train_idx], y_full[test_idx]

    # Train Random Forest model with optimized parameters by optuna
    def objective(trial):
        n_estimators = trial.suggest_int("n_estimators", 50, 200)
        max_depth    = trial.suggest_int("max_depth", 5, 20)
        min_split    = trial.suggest_int("min_samples_split", 2, 10)
        rf_model = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_split,
            random_state=42,
            n_jobs=-1
        )
        inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scores = cross_val_score(rf_model, X_outer_train, y_outer_train, cv=inner_cv, scoring='accuracy')

        return np.mean(scores)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=50)

    # Best model on fold prediction
    best_model = RandomForestClassifier(**study.best_params, random_state=42, n_jobs=-1)
    best_model.fit(X_outer_train, y_outer_train)
    y_pred = best_model.predict(X_outer_test)

    outer_acc.append(accuracy_score(y_outer_test, y_pred))
    outer_prec.append(precision_score(y_outer_test, y_pred, average='macro'))
    outer_rec.append(recall_score(y_outer_test, y_pred, average='macro'))
    outer_f1.append(f1_score(y_outer_test, y_pred, average='macro'))

    fold_idx += 1
t_optuna = time.time() - start

acc_optuna = study.best_value
best_trial = study.best_trial.number

print("Optuna:", study.best_params, "Acc:", acc_optuna, "Time:", round(t_optuna,2),"s")
# Out:
# --- Fold 1/5 ---
# --- Fold 2/5 ---
# --- Fold 3/5 ---
# --- Fold 4/5 ---
# --- Fold 5/5 ---
# Optuna: {'n_estimators': 130, 'max_depth': 17, 'min_samples_split': 3} Acc: 0.8915646258503401 Time: 108.97 s

# %%
# === NESTED CROSS VALIDATION results
acc_mean, acc_std = np.mean(outer_acc) * 100, np.std(outer_acc) * 100
prec_mean, prec_std = np.mean(outer_prec) * 100, np.std(outer_prec) * 100
rec_mean, rec_std = np.mean(outer_rec) * 100, np.std(outer_rec) * 100
f1_mean, f1_std = np.mean(outer_f1) * 100, np.std(outer_f1) * 100
print("\n=== Final results of NESTED CV with Optuna: Random Forest===")
print(f"Accuracy:  {acc_mean:.1f}% ± {acc_std:.1f}%")
print(f"Precision: {prec_mean:.1f}% ± {prec_std:.1f}%")
print(f"Recall:    {rec_mean:.1f}% ± {rec_std:.1f}%")
print(f"F1-Score:  {f1_mean:.1f}% ± {f1_std:.1f}%")
# Out:
# === Final results of NESTED CV with Optuna: Random Forest===
# Accuracy:  90.2% ± 2.1%
# Precision: 90.8% ± 1.9%
# Recall:    90.1% ± 2.0%
# F1-Score:  90.1% ± 2.0%

# %%
# === FINAL MODEL TRAINING AND EVALUATION ===
def final_objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 50, 200)
    max_depth = trial.suggest_int("max_depth", 5, 20)
    min_split = trial.suggest_int("min_samples_split", 2, 10)

    rf_model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_split,
        random_state=42,
        n_jobs=-1
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(rf_model, X_train, y_train, cv=cv, scoring='accuracy')
    return np.mean(scores)

final_study = optuna.create_study(direction="maximize")
final_study.optimize(final_objective, n_trials=50)

best_global_model = RandomForestClassifier(**final_study.best_params, random_state=42, n_jobs=-1)
best_global_model.fit(X_train, y_train)
y_pred = best_global_model.predict(X_test)

print("\nTest Accuracy:", round(accuracy_score(y_test, y_pred), 4))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9286
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.93      1.00      0.97        14
#            2       0.92      0.86      0.89        14
#            3       0.87      0.93      0.90        14
#
#     accuracy                           0.93        56
#    macro avg       0.93      0.93      0.93        56
# weighted avg       0.93      0.93      0.93        56

# %%
# === CONFUSION MATRIX ===
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=y_map)
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix - Random Forest")
plt.savefig(os.path.join(RESULTS_DIR, 'RF_CM.png'))
plt.show()

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
model = RandomForestClassifier(**final_study.best_params, random_state=42, n_jobs=-1)
fold_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')

plt.figure(figsize=(6,4))
plt.plot(range(1, 6), fold_scores, marker='o')
plt.title("Accuracy per fold (5-fold CV)")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %%
# === FEATURES IMPORTANCES ===
importances = pd.Series(best_global_model.feature_importances_, index=feature_cols).sort_values(ascending=False)
plt.figure(figsize=(8, 5))
importances.head(10).plot(kind='barh')
plt.title(f"Top 10 Feature Importances ({type(best_model).__name__})")
plt.xlabel("Mean Decrease in Score")
plt.gca().invert_yaxis()
plt.savefig(os.path.join(RESULTS_DIR, 'RF_feature_importance.png'))
plt.show()

# %%
# === SAVING MODEL ===
MODEL_PATH = os.path.join(MODELS_DIR, 'random_forest.pkl')
joblib.dump(best_model, MODEL_PATH)
print(f"\nModel saved to: {MODEL_PATH}")

encoder_filename = 'label_encoder.pkl'
encoder_path = os.path.join(MODELS_DIR, encoder_filename)
joblib.dump(le, encoder_path)
print(f"Label Encoder saved to: {encoder_path}")
# Out:
# Model saved to: C:\Users\Jakub\Kuba_lokalne\studia\Praca_magisterska\Projekt\Fault-detection-in-mechanical-devices\models\random_forest\random_forest.pkl
# Label Encoder saved to: C:\Users\Jakub\Kuba_lokalne\studia\Praca_magisterska\Projekt\Fault-detection-in-mechanical-devices\models\random_forest\label_encoder.pkl
